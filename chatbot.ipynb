# %% [markdown]
# # import section

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow import keras 
from keras.models import Sequential
from keras.layers import Dense ,Activation , Dropout
from tensorflow.keras.optimizers import SGD
import random

# %%
words = []
classes = []
documents = []
ignore_words = ['!' , '?']
data_file = open('intents.json',encoding="utf8").read()
intents = json.loads(data_file)

# %% [markdown]
# ### intents file:
# {
#
# "intents": [
#
# {"tag": "greeting",
#
# "patterns": ["Hi", "How are you", "Is anyone there?", "Hello", "Good day", "Whats up"],
#
# "responses": ["Hello!", "Good to see you again!", "Hi there, how can I help?"],
#
# "context_set": ""
#
# }, ... ] }

# %% [markdown]
# ## get data out of the intent to our list

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
    if intent['tag'] not in classes:
        classes.append(intent['tag'])
print(classes)
# Out:
# ['greeting', 'goodbye', 'name', 'gpa', 'gpa2', 'credithours', 'credithours2', 'specialize', 'Math211', 'Math231', 'Math271', 'Cs201', 'Stat201', 'Cs202', 'Math272', 'Math232', 'Math213', 'Math212', 'Math241', 'Cs302', 'Cs304', 'Cs305', 'Cs307', 'Cs309', 'Math305', 'Math351', 'Math355', 'Math361', 'Cs316', 'Cs303', 'Cs306', 'Cs308', 'Math306', 'Math352', 'Math356', 'Math362', 'Cs317', 'Math481', 'Math482', 'Math442', 'Math441', 'Cs401', 'Cs403', 'Cs406', 'Cs426', 'Cs428', 'Cs490', 'Cs427', 'Cs408', 'Cs407', 'Cs402']

# %% [markdown]
# example :
#
# documents = >
# [ (['Hi'], 'greeting') , (['How', 'are', 'you'], 'greeting') , (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting')]
#
# words => ['Hi', 'How', 'are', 'you', 'Is']
#
# classes = > ['greeting', 'goodbye', 'name', 'gpa', 'gpa2']

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if  w not in ignore_words]
# get red of dublications 
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
print(len(documents),' documents')
print(len(classes),' classes')
print(len(words),' unique lemmatized words')
# Out:
# 509  documents
# 51  classes
# 205  unique lemmatized words

# %%
pickle.dump(words, open('words.pkl','wb'))
pickle.dump(classes, open('classes.pkl','wb'))

# %% [markdown]
# ## create train and testing data

# %%
training = []
output_empty = [0] * len(classes)
## 
# make bag of word for each doc
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(w.lower()) for w in pattern_words if w not in ignore_words]
                   
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
        
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag , output_row])

# %%
# random the data
random.shuffle(training)
training = np.array(training)

train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# C:\Users\mahmoud\anaconda3\envs\test\lib\site-packages\ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model = Sequential()
model.add(Dense(128,input_shape = (len(train_x[0]),), activation = 'relu' ))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu' ))
model.add(Dropout(0.5))
model.add(Dense( len(train_y[0]), activation = 'softmax' ))

sgd = SGD(learning_rate=0.01, decay=1e-6 , momentum=0.9,nesterov = True)
model.compile(loss='categorical_crossentropy',optimizer = sgd,metrics=['accuracy'])

# train the model and save 
hist = model.fit(np.array(train_x),np.array(train_y),epochs=200 , batch_size = 5 , verbose = 1)
model.save('chat_model.h5',hist)
# Out:
# Epoch 1/200
# 102/102 [==============================] - 1s 1ms/step - loss: 3.9650 - accuracy: 0.0079
# Epoch 2/200
# 102/102 [==============================] - 0s 1ms/step - loss: 3.9038 - accuracy: 0.0295
# Epoch 3/200
# 102/102 [==============================] - 0s 1ms/step - loss: 3.9039 - accuracy: 0.0255
# Epoch 4/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.8631 - accuracy: 0.0354
# Epoch 5/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.8723 - accuracy: 0.0334
# Epoch 6/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.8107 - accuracy: 0.0432
# Epoch 7/200
# 102/102 [==============================] - 0s 1ms/step - loss: 3.8098 - accuracy: 0.0472
# Epoch 8/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.7291 - accuracy: 0.0707
# Epoch 9/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.6588 - accuracy: 0.0707
# Epoch 10/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.5754 - accuracy: 0.0884
# Epoch 11/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.5005 - accuracy: 0.1277
# Epoch 12/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.3742 - accuracy: 0.1375
# Epoch 13/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.2454 - accuracy: 0.1434
# Epoch 14/200
# 102/102 [==============================] - 0s 2ms/step - loss: 3.0954 - accuracy: 0.1788
# Epoch 15/200
# 102/102 [==============================] - 0s 2ms/step - loss: 2.9100 - accuracy: 0.2259
# Epoch 16/200
# 102/102 [==============================] - 0s 2ms/step - loss: 2.7019 - accuracy: 0.2672
# Epoch 17/200
# 102/102 [==============================] - 0s 2ms/step - loss: 2.5225 - accuracy: 0.3222
# Epoch 18/200
# 102/102 [==============================] - 0s 2ms/step - loss: 2.3050 - accuracy: 0.4028
# Epoch 19/200
# 102/102 [==============================] - 0s 2ms/step - loss: 2.0819 - accuracy: 0.4283
# Epoch 20/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.9957 - accuracy: 0.4578
# Epoch 21/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.7614 - accuracy: 0.5167
# Epoch 22/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.7418 - accuracy: 0.4990
# Epoch 23/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.6793 - accuracy: 0.5128
# Epoch 24/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.5334 - accuracy: 0.5540
# Epoch 25/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.5256 - accuracy: 0.5737
# Epoch 26/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.4476 - accuracy: 0.5737
# Epoch 27/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.4073 - accuracy: 0.5619
# Epoch 28/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.3254 - accuracy: 0.5992
# Epoch 29/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.2179 - accuracy: 0.6346
# Epoch 30/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.1215 - accuracy: 0.6739
# Epoch 31/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.1657 - accuracy: 0.6699
# Epoch 32/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.0514 - accuracy: 0.6837
# Epoch 33/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.1065 - accuracy: 0.6523
# Epoch 34/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.0965 - accuracy: 0.6640
# Epoch 35/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.9820 - accuracy: 0.7014
# Epoch 36/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.9767 - accuracy: 0.7230
# Epoch 37/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.9443 - accuracy: 0.7230
# Epoch 38/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.1292 - accuracy: 0.6699
# Epoch 39/200
# 102/102 [==============================] - 0s 2ms/step - loss: 1.0439 - accuracy: 0.6857
# Epoch 40/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.8701 - accuracy: 0.7348
# Epoch 41/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7905 - accuracy: 0.7583
# Epoch 42/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.8311 - accuracy: 0.7525
# Epoch 43/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.8381 - accuracy: 0.7485
# Epoch 44/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7784 - accuracy: 0.7662
# Epoch 45/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.9016 - accuracy: 0.7092
# Epoch 46/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.8685 - accuracy: 0.7446
# Epoch 47/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.8880 - accuracy: 0.7348
# Epoch 48/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7576 - accuracy: 0.7819
# Epoch 49/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7620 - accuracy: 0.7721
# Epoch 50/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.7695 - accuracy: 0.7505
# Epoch 51/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7575 - accuracy: 0.7741
# Epoch 52/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6943 - accuracy: 0.7642
# Epoch 53/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.8035
# Epoch 54/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.8094
# Epoch 55/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.8546 - accuracy: 0.7308
# Epoch 56/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6669 - accuracy: 0.7976
# Epoch 57/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7118 - accuracy: 0.8035
# Epoch 58/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.8291
# Epoch 59/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.7143 - accuracy: 0.7741
# Epoch 60/200
# 102/102 [==============================] - ETA: 0s - loss: 0.7467 - accuracy: 0.78 - 0s 2ms/step - loss: 0.7187 - accuracy: 0.7839
# Epoch 61/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.6179 - accuracy: 0.8016
# Epoch 62/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.6413 - accuracy: 0.7996
# Epoch 63/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6678 - accuracy: 0.8094
# Epoch 64/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.6353 - accuracy: 0.7976
# Epoch 65/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5977 - accuracy: 0.8055
# Epoch 66/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.6870 - accuracy: 0.7957
# Epoch 67/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5621 - accuracy: 0.8350
# Epoch 68/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5352 - accuracy: 0.8409
# Epoch 69/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5172 - accuracy: 0.8310
# Epoch 70/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.8310
# Epoch 71/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.8075
# Epoch 72/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.6142 - accuracy: 0.8035
# Epoch 73/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.8330
# Epoch 74/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5385 - accuracy: 0.8310
# Epoch 75/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5212 - accuracy: 0.8507
# Epoch 76/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4817 - accuracy: 0.8468
# Epoch 77/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.8291
# Epoch 78/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4450 - accuracy: 0.8605
# Epoch 79/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.8428
# Epoch 80/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.8605
# Epoch 81/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5333 - accuracy: 0.8389
# Epoch 82/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5114 - accuracy: 0.8409
# Epoch 83/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.8232
# Epoch 84/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5268 - accuracy: 0.8468
# Epoch 85/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 0.8802
# Epoch 86/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5329 - accuracy: 0.8448
# Epoch 87/200
# 102/102 [==============================] - 0s 3ms/step - loss: 0.5769 - accuracy: 0.8507
# Epoch 88/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.8625
# Epoch 89/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.8585
# Epoch 90/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4200 - accuracy: 0.8605
# Epoch 91/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8546
# Epoch 92/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5224 - accuracy: 0.8409
# Epoch 93/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4239 - accuracy: 0.8546
# Epoch 94/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.8644
# Epoch 95/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.8782
# Epoch 96/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.8821
# Epoch 97/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4685 - accuracy: 0.8487
# Epoch 98/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5605 - accuracy: 0.8232
# Epoch 99/200
# 102/102 [==============================] - 0s 3ms/step - loss: 0.5261 - accuracy: 0.8527
# Epoch 100/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5527 - accuracy: 0.8291
# Epoch 101/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.8566
# Epoch 102/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4608 - accuracy: 0.8625
# Epoch 103/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8861
# Epoch 104/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.8585
# Epoch 105/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4185 - accuracy: 0.8743
# Epoch 106/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4431 - accuracy: 0.8605
# Epoch 107/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.8134
# Epoch 108/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5423 - accuracy: 0.8428
# Epoch 109/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5421 - accuracy: 0.8330
# Epoch 110/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.8369
# Epoch 111/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5295 - accuracy: 0.8330
# Epoch 112/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4862 - accuracy: 0.8566
# Epoch 113/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.8389
# Epoch 114/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8939
# Epoch 115/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4668 - accuracy: 0.8625
# Epoch 116/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4300 - accuracy: 0.8723
# Epoch 117/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5020 - accuracy: 0.8350
# Epoch 118/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.8625
# Epoch 119/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4355 - accuracy: 0.8507
# Epoch 120/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.8703
# Epoch 121/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4462 - accuracy: 0.8546
# Epoch 122/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4485 - accuracy: 0.8527
# Epoch 123/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.8605
# Epoch 124/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8762
# Epoch 125/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4930 - accuracy: 0.8546
# Epoch 126/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4020 - accuracy: 0.8743
# Epoch 127/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.8487
# Epoch 128/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3792 - accuracy: 0.8782
# Epoch 129/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3736 - accuracy: 0.8939
# Epoch 130/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4709 - accuracy: 0.8684
# Epoch 131/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4250 - accuracy: 0.8743
# Epoch 132/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5150 - accuracy: 0.8527
# Epoch 133/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4054 - accuracy: 0.8782
# Epoch 134/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4741 - accuracy: 0.8684
# Epoch 135/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8861
# Epoch 136/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3437 - accuracy: 0.8782
# Epoch 137/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.8802
# Epoch 138/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.8782
# Epoch 139/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5181 - accuracy: 0.8585
# Epoch 140/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4682 - accuracy: 0.8605
# Epoch 141/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4072 - accuracy: 0.8861
# Epoch 142/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5100 - accuracy: 0.8389
# Epoch 143/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4362 - accuracy: 0.8703
# Epoch 144/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3712 - accuracy: 0.8959
# Epoch 145/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8939
# Epoch 146/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5427 - accuracy: 0.8428
# Epoch 147/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4143 - accuracy: 0.8821
# Epoch 148/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3252 - accuracy: 0.8880
# Epoch 149/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8939
# Epoch 150/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8821
# Epoch 151/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4193 - accuracy: 0.8743
# Epoch 152/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.8546
# Epoch 153/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.8625
# Epoch 154/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8723
# Epoch 155/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8919
# Epoch 156/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4304 - accuracy: 0.8644
# Epoch 157/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4559 - accuracy: 0.8605
# Epoch 158/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3879 - accuracy: 0.8900
# Epoch 159/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3763 - accuracy: 0.8880
# Epoch 160/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3437 - accuracy: 0.9077
# Epoch 161/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3800 - accuracy: 0.8703
# Epoch 162/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.6036 - accuracy: 0.8350
# Epoch 163/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4282 - accuracy: 0.8782
# Epoch 164/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4815 - accuracy: 0.8644
# Epoch 165/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4670 - accuracy: 0.8703
# Epoch 166/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3693 - accuracy: 0.8978
# Epoch 167/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8880
# Epoch 168/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8939
# Epoch 169/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5215 - accuracy: 0.8585
# Epoch 170/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4339 - accuracy: 0.8684
# Epoch 171/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.8762
# Epoch 172/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.8350
# Epoch 173/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4806 - accuracy: 0.8487
# Epoch 174/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4418 - accuracy: 0.8684
# Epoch 175/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4063 - accuracy: 0.8821
# Epoch 176/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.8664
# Epoch 177/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5789 - accuracy: 0.8487
# Epoch 178/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4826 - accuracy: 0.8782
# Epoch 179/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5000 - accuracy: 0.8605
# Epoch 180/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5070 - accuracy: 0.8527
# Epoch 181/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4850 - accuracy: 0.8527
# Epoch 182/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8861
# Epoch 183/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4276 - accuracy: 0.8821
# Epoch 184/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4289 - accuracy: 0.8644
# Epoch 185/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5190 - accuracy: 0.8585
# Epoch 186/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4860 - accuracy: 0.8625
# Epoch 187/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4885 - accuracy: 0.8527
# Epoch 188/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8723
# Epoch 189/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4062 - accuracy: 0.8743
# Epoch 190/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.8664
# Epoch 191/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3685 - accuracy: 0.8919
# Epoch 192/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4366 - accuracy: 0.8644
# Epoch 193/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.4298 - accuracy: 0.8782
# Epoch 194/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3686 - accuracy: 0.8939
# Epoch 195/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.4461 - accuracy: 0.8900
# Epoch 196/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.5548 - accuracy: 0.8369
# Epoch 197/200
# 102/102 [==============================] - 0s 1ms/step - loss: 0.3629 - accuracy: 0.8684
# Epoch 198/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.3954 - accuracy: 0.8802
# Epoch 199/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5120 - accuracy: 0.8585
# Epoch 200/200
# 102/102 [==============================] - 0s 2ms/step - loss: 0.5282 - accuracy: 0.8644

# %% [markdown]
# # make predections

# %%
import nltk 
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from tensorflow.keras.models import load_model
model = load_model('chat_model.h5')
import json 
import random

intents = json.loads(open('intents.json',encoding="utf8").read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
print(classes)
# Out:
# ['Cs201', 'Cs202', 'Cs302', 'Cs303', 'Cs304', 'Cs305', 'Cs306', 'Cs307', 'Cs308', 'Cs309', 'Cs316', 'Cs317', 'Cs401', 'Cs402', 'Cs403', 'Cs406', 'Cs407', 'Cs408', 'Cs426', 'Cs427', 'Cs428', 'Cs490', 'Math211', 'Math212', 'Math213', 'Math231', 'Math232', 'Math241', 'Math271', 'Math272', 'Math305', 'Math306', 'Math351', 'Math352', 'Math355', 'Math356', 'Math361', 'Math362', 'Math441', 'Math442', 'Math481', 'Math482', 'Stat201', 'credithours', 'credithours2', 'goodbye', 'gpa', 'gpa2', 'greeting', 'name', 'specialize']

# %%
def clean_up_sentence(sent):
    sentence_words = nltk.word_tokenize(sent)
    sentence_word = [lemmatizer.lemmatize(w.lower()) for w in sentence_words]
    return sentence_words

# %%
def bow(sentence , words , show_details = True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for s in sentence_words:
        for i , w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print('found in beg: %s' % w)
    return (np.array(bag))

# %%
def predict_class(sentence , model):
    p = bow(sentence , words, show_details = False)
    res = model.predict(np.array([p]))[0]
    print(res)
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r > ERROR_THRESHOLD ]
    print(results)
    results.sort(key=lambda x: x[1] , reverse = True)
    return_list = []
    for r in results:
        return_list.append({'intent':classes[r[0]],'probability':str(r[1])})
    return return_list

# %%
predict_class('how specialize',model)
# Out:
# [7.9124968e-04 1.1117439e-05 9.6928825e-06 4.4764884e-04 1.1272946e-06
#  8.5448199e-05 5.9864567e-05 2.1933780e-05 1.5108005e-04 7.8775112e-05
#  5.1605381e-04 2.9535190e-06 2.5100110e-04 1.9247152e-03 4.8894250e-05
#  9.1372326e-04 4.6552108e-05 6.1680941e-04 1.0105707e-06 7.4830285e-07
#  2.1515606e-04 2.9599803e-05 4.4446480e-03 4.6035131e-03 1.6469385e-05
#  8.4125371e-05 5.0151505e-07 1.2626310e-05 1.2590676e-04 1.8886817e-03
#  2.2118927e-03 8.8341776e-03 2.3919147e-04 6.4549400e-05 1.2608351e-06
#  2.5910547e-04 1.1188297e-05 1.9224141e-04 6.9696862e-06 1.7439619e-05
#  7.7554034e-07 4.0680080e-04 1.8782941e-05 9.7200699e-04 7.6480895e-01
#  1.0209508e-01 3.9212587e-03 4.4521652e-03 9.0679377e-02 2.9162255e-03
#  4.8890989e-04]
# [[44, 0.76480895]]
# [{'intent': 'credithours2', 'probability': '0.76480895'}]

# %%
def getResponse(ints,intents_json):
    result =''
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    
    for i in list_of_intents:
        if(i['tag']==tag):
            result = random.choice(i['responses'])
            break
    return result

# %%
def chatbot_response(msg):
    ints = predict_class(msg,model)
    print(ints)
    res = getResponse(ints,intents)
    
    return res

# %%
chatbot_response('hi')
# Out:
# [{'intent': 'greeting', 'probability': '1.0'}]
# 'Hello!'
